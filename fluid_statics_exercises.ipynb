# %% [markdown]
# (section-fluid_statics_exercises)=
# # Fluid statics - exercises
#
# :::{note}
# Density of water $\rho_w=1000\,\mathsf{kg}/\mathsf{m}^3$ (unless otherwise stated)
#
# Gravitational acceleration $g=9.81\,\mathsf{m}/\mathsf{s}^2$
# :::
#
# ### Submerged surfaces
#
# :::{exercise} 💧
#
#
# ::::{dropdown} ✓ Check your answer
#
# ::::
#
# ::::{admonition} Solution
# :class: dropdown
#
#
# ::::

# %% [markdown]
# ### Buoyancy
#
# :::{exercise}📝
#
#
# ::::{dropdown} ✓ Check your answer
#
# ::::
#
# ::::{admonition} Solution
# :class: dropdown
#
# ::::
